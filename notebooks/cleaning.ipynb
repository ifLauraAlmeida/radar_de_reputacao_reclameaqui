# %% [markdown]
# ### Carregar o complaints.csv
#
# "Carregando o arquivo de reclamações da camada bronze para análise e limpeza."

# %%
import sys
from pathlib import Path

# %% [markdown]
# ### Remover duplicatas
#
# "Removendo duplicatas do DataFrame de reclamações, considerando o campo 'link' como identificador único."

# %%
sys.path.insert(0, str(Path().resolve().parent / "src"))

from processors.data_cleaner import clean_complaints_csv
# Out:
# Arquivo complaints.csv não encontrado. Execute a coleta antes de limpar.

# %% [markdown]
# ### Salvar arquivo limpo
#
# "Salvando o complaints.csv limpo, sem duplicatas, na camada bronze."

# %%
csv_path = Path("../docs/bronze/complaints.csv")
df_clean = clean_complaints_csv(csv_path)
print(f"Reclamações após limpeza: {len(df_clean)}")
# Out:
# Reclamações após limpeza: 255

# %% [markdown]
# ### Visualizar resultado
#
# "Visualizando as primeiras linhas do arquivo de reclamações após a limpeza."

# %%
df_clean.head()
# Out:
#    page                                              title  \
# 0     1  Sofá com defeito estrutural e falta de solução...
# 1     1  Sofá Vogue Retrátil apresenta defeitos em meno...
# 2     1  Sofá da Shopee com defeito: USB amassado, baru...
# 3     1                                  Nunca mais compro
# 4     1  Sofá com defeito: um lado afundando após 3 mes...
#
#                                                 link
# 0  https://www.reclameaqui.com.br/net-sofas/sofa-...
# 1  https://www.reclameaqui.com.br/net-sofas/sofa-...
# 2  https://www.reclameaqui.com.br/net-sofas/sofa-...
# 3  https://www.reclameaqui.com.br/net-sofas/nunca...
# 4  https://www.reclameaqui.com.br/net-sofas/sofa-...
